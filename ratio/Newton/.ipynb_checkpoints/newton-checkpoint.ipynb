# %%
class logit():
    def __init__(self, alpha = 1e-2):
        self.alpha = alpha

    def transform(self,x, alpha = None):
        assert torch.all(x<=1) and torch.all(x>=0), 'can only transform value between 0 and 1'
        if alpha is None:
            alpha = self.alpha
        return torch.logit(alpha*torch.ones_like(x) + x*(1-2*alpha))

    def inverse_transform(self, x, alpha = None):
        if alpha is None:
            alpha = self.alpha
        return (torch.sigmoid(x)-alpha*torch.ones_like(x))/(1-2*alpha)

    def log_det(self,x, alpha = None ):
        if alpha is None:
            alpha = self.alpha
        return torch.log((1-2*alpha)(torch.reciprocal(alpha*torch.ones_like(x) + x*(1-2*alpha)) + torch.reciprocal((1-alpha)*torch.ones_like(x) - x*(1-2*alpha))))

# %%
# %load_ext autoreload
# %autoreload 2
import torch
from matplotlib import image
import numpy
from tqdm import tqdm
from utils import * 


rgb = image.imread("newton.jpg")
lines, columns = rgb.shape[:-1]

def rgb2gray(rgb):
    return numpy.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
grey = torch.tensor(rgb2gray(rgb))

#Sample data according to image
vector_density = grey.flatten()
vector_density = vector_density/torch.sum(vector_density)
lines, columns = grey.shape
num_samples = 500000
cat = torch.distributions.Categorical(probs = vector_density)
categorical_samples = cat.sample([num_samples])
target_samples = torch.cat([((categorical_samples%columns + torch.rand(num_samples))/columns).unsqueeze(-1),((1-(categorical_samples//columns + torch.rand(num_samples))/lines)).unsqueeze(-1)], dim = -1)

logit_transform = logit(alpha = 1e-2)
transformed_samples = logit_transform.transform(target_samples)

mean = torch.mean(transformed_samples, dim = 0)
cov = torch.cov(transformed_samples.T)
instrumental = torch.distributions.MultivariateNormal(mean, (cov + cov.T)/2)
proposed_samples = instrumental.sample([num_samples])

# %%
fig = plt.figure(figsize =(8,12))
plt.tick_params(left = False, right = False , labelleft = False , 
                labelbottom = False, bottom = False) 
plot_image_2d_points(transformed_samples)

# %%
from classifiers import * 
binary_classif = BinaryClassifier(proposed_samples, transformed_samples,[512,512,512])
binary_classif.train(2,10000,lr = 1e-3, weight_decay = 0, verbose = True)
binary_classif.train(2,10000,lr = 5e-4, weight_decay = 5e-6, verbose = True)
binary_classif.train(2,10000,lr = 1e-4, weight_decay = 5e-6, verbose = True)
torch.save(binary_classif, 'model4.sav')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:03<00:00, 31.62s/it, loss = 34.007042; device = cuda]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:01<00:00, 30.67s/it, loss = 33.960457; device = cuda]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:01<00:00, 30.60s/it, loss = 33.926659; device = cuda]

# %%
fig = plt.figure(figsize =(8,12))
plt.tick_params(left = False, right = False , labelleft = False , 
                labelbottom = False, bottom = False) 
plot_2d_function(lambda x: torch.exp(binary_classif.logit_r(x).squeeze(-1) + instrumental.log_prob(x) + logit_transform.log_det(x)), bins = (lines, columns), range =[[-10.,10.],[-10.,10.]])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       1 fig = plt.figure(figsize =(8,12))
#       2 plt.tick_params(left = False, right = False , labelleft = False ,
#       3                 labelbottom = False, bottom = False)
# ----> 4 plot_2d_function(lambda x: torch.exp(binary_classif.logit_r(x).squeeze(-1) + instrumental.log_prob(x) + logit_transform.log_det(x)), bins = (lines, columns), range =[[-10.,10.],[-10.,10.]])
#
# File c:\users\elouan\pycharmprojects\models\venv\lib\site-packages\utils\visual.py:79, in plot_2d_function(f, range, bins, alpha, show)
#      77     mesh = torch.cartesian_prod(tt_x, tt_y)
#      78     with torch.no_grad():
# ---> 79         plt.pcolormesh(tt_x,tt_y,f(mesh).numpy().reshape(bins[0],bins[1]).T, cmap = matplotlib.cm.get_cmap('viridis'), alpha = alpha, lw = 0)
#      80 if show:
#      81     plt.show()
#
# Cell In[6], line 4, in <lambda>(x)
#       1 fig = plt.figure(figsize =(8,12))
#       2 plt.tick_params(left = False, right = False , labelleft = False ,
#       3                 labelbottom = False, bottom = False)
# ----> 4 plot_2d_function(lambda x: torch.exp(binary_classif.logit_r(x).squeeze(-1) + instrumental.log_prob(x) + logit_transform.log_det(x)), bins = (lines, columns), range =[[-10.,10.],[-10.,10.]])
#
# Cell In[2], line 19, in logit.log_det(self, x, alpha)
#      17 if alpha is None:
#      18     alpha = self.alpha
# ---> 19 return torch.log((1-2*alpha)(torch.inverse(alpha*torch.ones_like(x) + x*(1-2*alpha)) + torch.inverse((1-alpha)*torch.ones_like(x) - x*(1-2*alpha))))
#
# RuntimeError: linalg.inv: A must be batches of square matrices, but they are 94900 by 2 matrices

# %%
proposed_samples = instrumental.sample([num_samples])
unormalized_weights = torch.exp(binary_classif.logit_r(proposed_samples)).squeeze(-1)
normalized_weights = unormalized_weights/torch.sum(unormalized_weights)
cat = torch.distributions.Categorical(normalized_weights).sample([num_samples])
samples = proposed_samples[cat]
inverse_samples = logit_transform.inverse_transform(samples)

# %%
fig = plt.figure(figsize =(8,12))
plt.tick_params(left = False, right = False , labelleft = False , 
                labelbottom = False, bottom = False) 
plot_image_2d_points(inverse_samples)
