# %%
import matplotlib.pyplot as plt
import torch
import numpy

# %%
rgb = plt.imread('untitled.png')
plt.imshow(img)
def rgb2gray(rgb):
    return numpy.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
grey = torch.tensor(rgb2gray(rgb))
threshold = 0.69
mask = (grey>threshold)
print(mask.shape)
# Out:
# torch.Size([551, 619])

# %%
plt.imshow(mask, cmap  ='gray')

# %%
plt.imsave('signature.png', mask, cmap = 'gray')

# %%
print(img)
# Out:
# [[[0.7137255  0.7254902  0.7529412 ]
#   [0.7176471  0.7294118  0.75686276]
#   [0.98039216 0.98039216 0.98039216]
#   ...
#   [0.7490196  0.7490196  0.75686276]
#   [0.7490196  0.7490196  0.75686276]
#   [0.7529412  0.7529412  0.7607843 ]]
#
#  [[0.7137255  0.7254902  0.7529412 ]
#   [0.7176471  0.7294118  0.75686276]
#   [0.98039216 0.98039216 0.98039216]
#   ...
#   [0.7490196  0.7490196  0.75686276]
#   [0.7490196  0.7490196  0.75686276]
#   [0.7529412  0.7529412  0.7607843 ]]
#
#  [[0.7137255  0.7254902  0.7529412 ]
#   [0.9764706  0.98039216 0.98039216]
#   [0.98039216 0.98039216 0.98039216]
#   ...
#   [0.7490196  0.7490196  0.75686276]
#   [0.7490196  0.7490196  0.75686276]
#   [0.9372549  0.9372549  0.9411765 ]]
#
#  ...
#
#  [[0.99607843 0.99607843 0.99607843]
#   [0.99607843 0.99607843 0.99607843]
#   [0.99607843 0.99607843 0.99607843]
#   ...
#   [0.99607843 0.99607843 0.99607843]
#   [0.99607843 0.99607843 0.99607843]
#   [0.99607843 0.99607843 0.99607843]]
#
# ...
