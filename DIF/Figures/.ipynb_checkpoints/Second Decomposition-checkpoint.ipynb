# %%
import torch
import matplotlib.pyplot as plt

# %%
sin = lambda z : z + torch.sin(z*3)+ torch.sin(z)**2 - 1.50

# %%
tt = torch.linspace(-10,10, 500)
plt.plot(tt,sin(tt))

# %%
w  = lambda z: torch.softmax(torch.cat([sin(z).unsqueeze(-1), 0.5*torch.zeros_like(sin(z)).unsqueeze(-1)], dim = -1), dim = -1)

# %%
print(w(tt).shape)
# Out:
# torch.Size([500, 2])

# %%
plt.plot(tt,w(tt)[:,0])
plt.plot(tt,w(tt)[:,1])

# %%
plt.figure(figsize = (10,7))
ax = plt.subplot(111)
ax.tick_params(left=False,bottom=True,labelleft=False,labelbottom=True)
gauss0 = torch.distributions.MultivariateNormal(torch.tensor([-4.5]), 1.5*torch.eye(1))
gauss1 = torch.distributions.MultivariateNormal(torch.tensor([4.5]), 1.5*torch.eye(1))
ax.plot(tt, torch.exp(gauss0.log_prob(tt.unsqueeze(-1))), color = 'C1', linestyle = '--',label = r'$\mathcal{N}(x;\mu_1, \Sigma_1)$')
tt0 = torch.linspace(-7, -1, 200)
ax.plot(tt0, w(tt0 + 4.5)[:,0], color = 'C1', linestyle = 'dotted', label =  r'$\pi_1(x)$')
ax.plot(tt, torch.exp(gauss1.log_prob(tt.unsqueeze(-1))), color = 'C2', linestyle = '--', label = r'$\mathcal{N}(x;\mu_1, \Sigma_1)$')
tt1 = torch.linspace(7, 1, 200)
ax.plot(tt1, w(tt1 - 4.5)[:,1], color = 'C2', linestyle = 'dotted', label = r'$\pi_2(x)$')
ax.plot(tt,w(tt + 4.5)[:,0]*torch.exp(gauss0.log_prob(tt.unsqueeze(-1))) + w(tt-4.5)[:,1]*torch.exp(gauss1.log_prob(tt.unsqueeze(-1))), color = 'C4', label = r'$\psi(x)$')
plt.legend(ncol = 2, fontsize = 15)
